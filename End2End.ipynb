# %%
import pandas as pd
df=pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
print(df['Fuel_Type'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]
# ['Petrol' 'Diesel' 'CNG']

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_df=df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_df['Current_year']=2021

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_year
# 0       Manual      0          2021
# 1       Manual      0          2021
# 2       Manual      0          2021
# 3       Manual      0          2021
# 4       Manual      0          2021

# %%
final_df['years_old']=final_df['Current_year']-final_df['Year']

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_year  years_old
# 0       Manual      0          2021          7
# 1       Manual      0          2021          8
# 2       Manual      0          2021          4
# 3       Manual      0          2021         10
# 4       Manual      0          2021          7

# %%
final_df.drop(['Year'],axis=1,inplace=True)
final_df.drop(['Current_year'],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  years_old
# 0       Manual      0          7
# 1       Manual      0          8
# 2       Manual      0          4
# 3       Manual      0         10
# 4       Manual      0          7

# %%
#final_df.drop(['Current_year'],axis=1,inplace=True)

# %%
#final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  years_old
# 0       Manual      0          7
# 1       Manual      0          8
# 2       Manual      0          4
# 3       Manual      0         10
# 4       Manual      0          7

# %%
final_df=pd.get_dummies(final_df,drop_first=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  years_old  \
# 0           3.35           5.59       27000      0          7
# 1           4.75           9.54       43000      0          8
# 2           7.25           9.85        6900      0          4
# 3           2.85           4.15        5200      0         10
# 4           4.60           6.87       42450      0          7
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
final_df.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# years_old                   -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         years_old  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price           -0.236141          0.552339         -0.540571
# Present_Price            0.047584          0.473306         -0.465244
# Kms_Driven               0.524342          0.172515         -0.172874
# Owner                    0.182104         -0.053469          0.055687
# years_old                1.000000         -0.064315          0.059959
# Fuel_Type_Diesel        -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol         0.059959         -0.979648          1.000000
# Seller_Type_Individual   0.039896         -0.350467          0.358321
# Transmission_Manual     -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# years_old                             0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
import seaborn as sns
sns.pairplot(final_df)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corrmat=final_df.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
vis=sns.heatmap(final_df[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %%
x=final_df.iloc[:,1:]
y=final_df.iloc[:,0]

# %%
#feature importance
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.39145257 0.04264586 0.00068274 0.0752442  0.22977211 0.01163704
#  0.11526727 0.13329822]

# %%
feat_imp=pd.Series(model.feature_importances_,index=x.columns)
feat_imp.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_test.shape
# Out:
# (91, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random=RandomForestRegressor()

# %%
#hyperparameters 
import numpy as np
n_estimators=[int(x) for x in np.linspace(start=100,stop=1500,num=12)]

# %%
print(n_estimators)
# Out:
# [100, 227, 354, 481, 609, 736, 863, 990, 1118, 1245, 1372, 1500]

# %%
max_depth=[int(x) for x in np.linspace(5,30,num=6)]
max_features=['auto','sqrt']
min_samples_split=[2,5,10,12,25]
min_samples_leaf=[1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid={'n_estimators':n_estimators,'max_depth':max_depth,'max_features':max_features,'min_samples_split':min_samples_split,'min_samples_leaf':min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 227, 354, 481, 609, 736, 863, 990, 1118, 1245, 1372, 1500], 'max_depth': [5, 10, 15, 20, 25, 30], 'max_features': ['auto', 'sqrt'], 'min_samples_split': [2, 5, 10, 12, 25], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf=RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.2s remaining:    0.0s
# [CV]  n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   2.9s
# [CV] n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1118, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.0s
# [CV] n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   3.8s
# [CV] n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   4.1s
# [CV] n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   4.1s
# [CV] n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   3.4s
# [CV] n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1372, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   3.5s
# [CV] n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   0.9s
# [CV] n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.0s
# [CV] n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=354, min_samples_split=25, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.3s
# [CV] n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.5s
# [CV] n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.6s
# [CV] n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.5s
# [CV] n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.6s
# [CV] n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=481, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.2s
# [CV] n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   2.8s
# [CV] n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   2.2s
# [CV] n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   2.3s
# [CV] n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   2.5s
# [CV] n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   2.8s
# [CV] n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   4.4s
# [CV] n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   3.6s
# [CV] n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   3.6s
# [CV] n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   3.5s
# [CV] n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1245, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   4.1s
# [CV] n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.6s
# [CV] n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.6s
# [CV] n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.5s
# [CV] n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.6s
# [CV] n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1372, min_samples_split=12, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.6s
# [CV] n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.9s
# [CV] n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=354, min_samples_split=12, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.6s
# [CV] n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.5s
# [CV] n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.3s
# [CV] n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.3s
# [CV] n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=863, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.6s
# [CV] n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.3s
# [CV] n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.9s
# [CV] n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.6s
# [CV] n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.6s
# [CV] n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=863, min_samples_split=12, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.6s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  2.1min finished
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 12, 25],
#                                         'n_estimators': [100, 227, 354, 481,
#                                                          609, 736, 863, 990,
#                                                          1118, 1245, 1372,
#                                                          1500]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
predictions=rf_random.predict(x_test)
predictions
# Out:
# array([ 3.60161446,  0.44858635,  0.67440161,  0.6808996 ,  2.86840161,
#         0.50844177,  8.05637751,  0.55538153,  2.76230522,  3.84461847,
#         6.02452209,  5.96388755,  1.11750201,  4.96546185,  3.78587952,
#         0.25383936,  7.49195181,  3.79646586,  7.20218474,  3.97024096,
#         5.61855422,  5.55854618,  2.60102008,  0.49030522,  1.12572691,
#         4.07869076,  0.53782329,  5.0026988 ,  7.24763052,  0.6875261 ,
#         0.58853815,  4.2662249 ,  6.41441767,  0.53040161,  8.22167871,
#         0.66641767,  8.66164659,  0.33668273,  7.84803213,  4.37498795,
#         7.01707631,  5.02567068,  3.59329317,  5.81052209,  0.75970281,
#        11.55187952,  0.61492369,  0.47526104,  7.97570281,  0.83140562,
#         0.45244177, 22.08967871,  5.63594378, 10.40062651,  8.52083534,
#         1.00537349,  3.74837751,  0.58929317,  4.00907631,  3.66973494,
#         0.47273092,  0.64629719,  6.17143775,  4.98180723,  5.25146988,
#         4.21864257,  5.83958233,  8.73391968,  5.60500402,  2.87824096,
#         0.47085141,  0.64347791,  1.36413655,  4.46911647,  0.6262249 ,
#         0.77618474,  0.97645783,  9.34815261,  7.32659438,  6.040249  ,
#         3.93927711,  4.49421687,  0.46629719,  1.19884337, 12.62845783,
#         0.54141365,  2.41281124,  5.05060241,  1.07371888,  5.08137349,
#         6.2853012 ])

# %%
sns.distplot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
#create pickle file
import pickle
file=open("random_forest_model.pkl",'wb')
#dump info of file
pickle.dump(rf_random,file)
